# %% [markdown]
# <a href="https://colab.research.google.com/github/asfanjamil/EDA-project-AIRBNb/blob/main/Asfan_Airbnb_booking_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
#
# ### > Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more.
# This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ### **Explore and analyze the data to discover key understandings (not limited to these) such as :**
# ### .**check out the last_review wise count of where availability_365 is 0?**
#
# ### **.What can we learn about different hosts and areas?**
#
# ### **.What can we learn from predictions? (ex: locations, prices, reviews, etc)**
#
# ### **.Which hosts are the busiest and why?**
# ### **Is there any noticeable difference of traffic among different areas and what could be the reason for it**
# ### **.Different charts are used for data visualization so that better insights and business objective is attend**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ### **. Profit Earning.**
#
# ### **. Market Share / Creation of Customers**
#
# ### **.Innovation & Utilization of Resources**
# ### **.Increasing Productivity**
# ### **.Customer satisfaction**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %shell  %store  %sx  %system  %tb  %tensorflow_version  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Airbnb NYC 2019.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First look
df.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count 
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count 
df.drop_duplicates(inplace = True)

# %%
uni_num_of_rows = df.shape[0]

# %%
uni_num_of_rows
# Out:
# 48895

# %%
df.reset_index()  # View unique data
# Out:
#        index        id                                               name  \
# 0          0      2539                 Clean & quiet apt home by the park
# 1          1      2595                              Skylit Midtown Castle
# 2          2      3647                THE VILLAGE OF HARLEM....NEW YORK !
# 3          3      3831                    Cozy Entire Floor of Brownstone
# 4          4      5022   Entire Apt: Spacious Studio/Loft by central park
# ...      ...       ...                                                ...
# 48890  48890  36484665    Charming one bedroom - newly renovated rowhouse
# 48891  48891  36485057      Affordable room in Bushwick/East Williamsburg
# 48892  48892  36485431            Sunny Studio at Historical Neighborhood
# 48893  48893  36485609               43rd St. Time Square-cozy single bed
# 48894  48894  36487245  Trendy duplex in the very heart of Hell's Kitchen
#
#         host_id      host_name neighbourhood_group       neighbourhood  \
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count 
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values 
df.loc[:,df.isna().sum()!=0]
# Out:
#                                                     name      host_name  \
# 0                     Clean & quiet apt home by the park           John
# 1                                  Skylit Midtown Castle       Jennifer
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      Elisabeth
# 3                        Cozy Entire Floor of Brownstone    LisaRoxanne
# 4       Entire Apt: Spacious Studio/Loft by central park          Laura
# ...                                                  ...            ...
# 48890    Charming one bedroom - newly renovated rowhouse        Sabrina
# 48891      Affordable room in Bushwick/East Williamsburg        Marisol
# 48892            Sunny Studio at Historical Neighborhood  Ilgar & Aysel
# 48893               43rd St. Time Square-cozy single bed            Taz
# 48894  Trendy duplex in the very heart of Hell's Kitchen     Christophe
#
#       last_review  reviews_per_month
# 0      2018-10-19               0.21
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This data set contains a single file which compares various booking information such as
# host_name ,	neighbourhood_group ,	neighbourhood,	latitude,	longitude,	room_type,	price,	minimum_nights,	number_of_reviews,	last_review,	reviews_per_month,	calculated_host_listings_count,	availability_365 ,
#
# data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts) behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix between categorical and numeric values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns 
df_column = df.columns
df_column
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe 
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable. 
print(df.apply(lambda x: x.unique()))   # We have describes unique value in all individual column.
# Out:
# id                                [2539, 2595, 3647, 3831, 5022, 5099, 5121, 517...
# name                              [Clean & quiet apt home by the park, Skylit Mi...
# host_id                           [2787, 2845, 4632, 4869, 7192, 7322, 7356, 896...
# host_name                         [John, Jennifer, Elisabeth, LisaRoxanne, Laura...
# neighbourhood_group               [Brooklyn, Manhattan, Queens, Staten Island, B...
# neighbourhood                     [Kensington, Midtown, Harlem, Clinton Hill, Ea...
# latitude                          [40.64749, 40.75362, 40.80902, 40.68514, 40.79...
# longitude                         [-73.97237, -73.98377, -73.9419, -73.95976, -7...
# room_type                              [Private room, Entire home/apt, Shared room]
# price                             [149, 225, 150, 89, 80, 200, 60, 79, 135, 85, ...
# minimum_nights                    [1, 3, 10, 45, 2, 5, 4, 90, 7, 14, 60, 29, 30,...
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
# Write your code to make your dataset analysis ready.
percentage_of_data_having_availbility_0= round((len(df[df['availability_365']==0]['availability_365'])/len(df['availability_365']))*100,2)
print(f'the percentage of data having availibity as 0 is {percentage_of_data_having_availbility_0}')
# Out:
# the percentage of data having availibity as 0 is 35.86

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# So we can clearly notice that availiabilty column is having minmum value as well as 25th percentile is 0 , so this seems awkward beacuse having availability days 0 for 36% of data is bit shocking , If you have a business of providing shelters for Airbnb your availibility is 0 days that is extreme case and extreme cases is obviously shocking when it comes 36% of data is having extreme case
#
# but its not practicaly possible to exactly detect which apartments are having realy availabilty 0 days , so we will not alter this column as if we try to alter we can end up manipulating appartments which are really mostly busy (i.e 0 no. of days availibility )
#
# ### We can also clearly see that minimum price is 0 , which is surprising as price 0 doesnt make sense to do business

# %%
#Q1 check out the last_review wise count of where availability_365 is 0?
df[df['availability_365']==0].groupby(['last_review']).size().sort_values(ascending=False).head(15)
# Out:
# last_review
# 2019-01-01    194
# 2018-01-01    142
# 2019-01-02    129
# 2019-06-23     90
# 2018-01-02     86
# 2017-01-01     85
# 2019-05-27     75
# 2017-01-02     73
# 2016-01-02     67
# 2019-07-01     63
# 2016-01-03     61
# 2018-12-30     61
# 2019-01-03     60
# 2019-06-24     59
# 2018-12-31     57
# dtype: int64

# %% [markdown]
# **lets fill these datas with appropriate price values (by filling the price with median price for each room_type**)

# %%
df.loc[ (df.room_type=='Entire home/apt') & (df.price==0),'price']=df.loc[ (df.room_type=='Entire home/apt') & (df.price!=0),'price'].median()
df.loc[ (df.room_type=='Private room') & (df.price==0),'price']=df.loc[ (df.room_type=='Private room') & (df.price!=0),'price'].median()
df.loc[ (df.room_type=='Shared room') & (df.price==0),'price']=df.loc[ (df.room_type=='Shared room') & (df.price!=0),'price'].median()

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.739094
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.146276
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420     10.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ## **NOTE: We can notice that we have succesfully updated the price column where we have values as 0 , we succesfully updated the value with respective price value**

# %%
#Q2 . What can we learn about different hosts and areas?

# %%
hosts_areas = df.groupby(['host_name','host_id','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
hosts_areas.sort_values(by='calculated_host_listings_count', ascending=False).head(5)
# Out:
#           host_name    host_id neighbourhood_group  \
# 33329  Sonder (NYC)  219517861           Manhattan
# 4884     Blueground  107434423            Brooklyn
# 4885     Blueground  107434423           Manhattan
# 19038          Kara   30283594           Manhattan
# 19674        Kazuya  137358866              Queens
#
#        calculated_host_listings_count
# 33329                             327
# 4884                              232
# 4885                              232
# 19038                             121
# 19674                             103

# %% [markdown]
# ### **As we can see most number of listings are from Manhattan created Sonder (NYC), Blueground**

# %% [markdown]
# ### **So Sonder (NYC) is having maximum numbers of rooms for the guest, For Airbnb he might be very important person then**

# %%
df_sonder=df[df['host_name']=='Sonder (NYC)']
df_sonder[['host_name','neighbourhood_group','neighbourhood','latitude','longitude']].head(6)
# Out:
#           host_name neighbourhood_group       neighbourhood  latitude  \
# 38293  Sonder (NYC)           Manhattan  Financial District  40.70637
# 38294  Sonder (NYC)           Manhattan  Financial District  40.70771
# 38588  Sonder (NYC)           Manhattan  Financial District  40.70743
# 39769  Sonder (NYC)           Manhattan         Murray Hill  40.74792
# 39770  Sonder (NYC)           Manhattan         Murray Hill  40.74771
# 39771  Sonder (NYC)           Manhattan         Murray Hill  40.74845
#
#        longitude
# 38293  -74.00645
# 38294  -74.00641
# 38588  -74.00443
# 39769  -73.97614
# 39770  -73.97528
# 39771  -73.97446

# %% [markdown]
# **so Sonder (NYC) is having multiple appartments in same building in different different neighbourhood**

# %%
 # will keep only the availability_365 > 0, beacuse availability_365 =0 doesnt required for the analysis this availability_365=0 most probably listings have stopped thier buisness with Airbnb
# we will keep only the availability_365 > 0, beacuse availability_365 =0 doesnt required for the analysis
# this availability_365=0  most probably listings have stopped thier buisness with Airbnb 

df=df[df['availability_365']>0]

# %%
df['minimum_nights'].describe()
# Out:
# count    31362.000000
# mean         8.338658
# std         23.836703
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# **we can notice that there are some outliers in the minimum_nights as for availability_365 is calculated for the period of 365 days**

# %%
# we will take minimum_nights <=365 only as it makes sense
df=df[df['minimum_nights']<=365]

# %%
# designing the matrix

# %% [markdown]
# **Firstly, the metric needs the available months (one period of business) the host is open for business/accepting bookings :-**
#
# **available months = available days / (365/12)**
#
# For the given months the property is open for business, next is to estimate the maximum possible bookings a property can have through the available days, here the assumption is that, every customer stays exactly equal to minimum nights required by the listing :-
#
# total possible bookings = available days / minimum nights
# estimated bookings = reviews per month x available months Using all the above calculations, the percentage of occupancy throughout the year is gives as :-
#
# occupancy % = estimated bookings / total possible bookings x 100

# %%
# create matrix for above
avg_month_length = 30
df['availability_months'] = df.availability_365 / avg_month_length

df['max_possible_bookings'] = df.availability_365 / df.minimum_nights
df['booking_estimate'] = df.reviews_per_month * df.availability_months


df = df[df.booking_estimate <= df.max_possible_bookings]

df['occupancy_percentage'] = (df.booking_estimate / df.max_possible_bookings) * 100
df.head(10)
# Out:
# <ipython-input-27-9097bf192cf7>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['occupancy_percentage'] = (df.booking_estimate / df.max_possible_bookings) * 100
#       id                                              name  host_id  \
# 0   2539                Clean & quiet apt home by the park     2787
# 1   2595                             Skylit Midtown Castle     2845
# 3   3831                   Cozy Entire Floor of Brownstone     4869
# 5   5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 7   5178                  Large Furnished Room Near B'way      8967
# 9   5238                Cute & Cozy Lower East Side 1 bdrm     7549
# 10  5295                  Beautiful 1br on Upper West Side     7702
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %%
df['neighbourhood'].value_counts().head(10)
# Out:
# Bedford-Stuyvesant    2159
# Williamsburg          1756
# Harlem                1468
# Bushwick              1192
# Hell's Kitchen        1178
# Upper East Side        883
# Upper West Side        842
# East Village           798
# Crown Heights          786
# Midtown                682
# Name: neighbourhood, dtype: int64

# %%
# plotting top 10 neighbourhood which are having maximum number of appartments for airbnb in the respective neighbourhood
pd.value_counts(df['neighbourhood'])[:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        10589
# Brooklyn         10481
# Queens            3613
# Bronx              753
# Staten Island      284
# Name: neighbourhood_group, dtype: int64

# %%
pd.value_counts(df['neighbourhood_group']).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# . plot the bar chart for top 10 neighbourhood and also plot the bar chart for neighbourhood_group** ****

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# firstly we find the Which are the top 10 neighbourhood which are having maximum number of appartments for airbnb ? and secondly which are neighbourhood_group city having the most a appartment

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **YES manhattan Provided more services to attract more guest to increase more revenue that is a psitive growth**

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code /What can we learn from predictions? (ex: locations, prices, reviews, etc)
areas_reviews = df.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
areas_reviews
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx                321
# 1            Brooklyn                488
# 2           Manhattan                607
# 3              Queens                629
# 4       Staten Island                333

# %%
area = areas_reviews['neighbourhood_group']
review = areas_reviews['number_of_reviews']

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(area, review, color ='maroon',
        width = 0.4)
 
plt.xlabel("area")
plt.ylabel("review")
plt.title("Area vs Number of reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to plot bar chart for area vs review.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **as we can see that the more reviews came from the queens followed by Manhattan and brooklyn , and Staten Island and bronx have less reviews**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **theres is a positive bussiness impact on places like  queens , Manhattan and brooklyn because the reviews no. is more we can say that people like to visit this cities more in compare to Staten Island and bronx which is not good for bussiness**

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code 
price_area = df.groupby(['price'])['number_of_reviews'].max().reset_index()
price_area.head(5)
# Out:
#    price  number_of_reviews
# 0     10                 93
# 1     11                113
# 2     12                  8
# 3     13                  9
# 4     15                 19

# %%
area = price_area['price']
price = price_area['number_of_reviews']

# %%
fig = plt.figure(figsize = (10, 5))
 
# creating the scatter plot
plt.scatter(area, price)
 
plt.xlabel("Price")
plt.ylabel("Number of Review")
plt.title("Price vs Number of Reviews")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **use scatter to the relation between the price and number of reviews**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **From the above Analysis we can say that most people prefer to stay in place where price is less**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **from the above analysis we can say that the people love the places where price is less , so for Growth of business we have to be carefull with the price it should not be more .**

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code / What is the distribution of the room type and its distribution over the location ?
plt.figure(figsize=(8,5))
df['room_type'].value_counts().plot(kind='bar',color=['r','b','y'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **to see the how are room_type is distributed**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **that maximum numbers of room are Entire home/Apartment and Private room there are only few shared rooms**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ** from the above insights we can say So mostly host prefer to give Entire home/Appartment or Private Rooms rather than Shared room**
#
# **.**

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code / lets see how room_type is distributed over all location

plt.figure(figsize=(15,8))
sns.scatterplot(x=df['longitude'],y=df['latitude'], hue=df['room_type'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **scatter plot show the distribution of room types**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **how room_type is distributed over all location , which shows the people like to stay in private room**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### **The people who prefer to stay in Entire home or Apartment they are going to stay bit longer in that particular Neighbourhood only**

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code 
# first get rid of 0 price
df_price=df[df['price']!=0].copy()

# %%
sns.set_theme(style='whitegrid')
sns.boxplot(y='room_type',x='price',hue='room_type',palette='Set3',linewidth=1.5,fliersize=1.5 , data=df_price)
# Out:
# <AxesSubplot:xlabel='price', ylabel='room_type'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### **room type with respect to price**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **we can notice that there are many outliers for price in each of the room_type category.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **from the above, so lets just why there is so high price or what else we can conclude for hosts having highest price for the rooms**

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code 
avg_price_df = df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_price_df
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     122.188192     57.456180    58.648649
# Brooklyn                  179.143447     77.508822    45.058036
# Manhattan                 251.483121    115.087253    75.575188
# Queens                    145.443276     66.138140    66.560606
# Staten Island             123.751880     58.387755    67.000000

# %%
avg_price_df.plot.bar(figsize=(15,5),ylabel='Average Price calculated')
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='Average Price calculated'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### **applying groupby over 'neighbourhood_groups' and 'room_type'  then applying mean of price  and unstacking for clear visualization**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **As we can see that manhattan is most costly and bronx is cheap for each room_type**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ### **we can make it more useful for buissness implimentation if we do some analysis on successfull hosts according to the heighest no of reviews so that we can suggest this price to our host for good buisness**

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code / Which hosts are the busiest and why?
busiest_hosts = df.groupby(['host_name','host_id','room_type'])['number_of_reviews'].max().reset_index()
busiest_hosts = busiest_hosts.sort_values(by='number_of_reviews', ascending=False).head(10)
busiest_hosts
# Out:
#       host_name   host_id        room_type  number_of_reviews
# 4929       Dona  47621202     Private room                629
# 8758         Jj   4734398     Private room                607
# 12709      Maya  37312959     Private room                543
# 3021      Carol   2369681     Private room                540
# 4286   Danielle  26432133     Private room                510
# 1906        Asa  12949460  Entire home/apt                488
# 11115     Linda   2680820     Private room                474
# 1367     Angela  23591164     Private room                466
# 240       Agnes    277379     Private room                458
# 11309     Lloyd   2321321      Shared room                454

# %%
name = busiest_hosts['host_name']
reviews = busiest_hosts['number_of_reviews']

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(name, reviews, color ='maroon',
        width = 0.4)
 
plt.xlabel("Name of the Host")
plt.ylabel("Number of Reviews")
plt.title("Busiest Hosts")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **to show  Which hosts are the busiest and why**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Because these hosts listed room type as Entire home and Private room which is preferred by most number of people.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **these are the busiest hosts which are giving most no. of reviews**

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code 
traffic_areas = df.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
traffic_areas = traffic_areas.sort_values(by='minimum_nights', ascending=False)
traffic_areas
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt            6369
# 3             Brooklyn  Entire home/apt            5326
# 4             Brooklyn     Private room            4931
# 7            Manhattan     Private room            3954
# 10              Queens     Private room            2150
# 9               Queens  Entire home/apt            1331
# 1                Bronx     Private room             445
# 0                Bronx  Entire home/apt             271
# 8            Manhattan      Shared room             266
# 5             Brooklyn      Shared room             224
# 13       Staten Island     Private room             147
# 12       Staten Island  Entire home/apt             133
# 11              Queens      Shared room             132
# 2                Bronx      Shared room              37
# 14       Staten Island      Shared room               4

# %%
room_type = traffic_areas['room_type']
stayed = traffic_areas['minimum_nights']

fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(room_type, stayed, color ='m',
        width = 0.4)
 
plt.xlabel("Room Type")
plt.ylabel("Minimum number of nights stayed")
plt.title("Traffic Areas")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ### **Is there any noticeable difference of traffic among different areas**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **From the Above Analysis We can Stay that People are preferring Entire home/apt or Private room which are present in Manhattan, Brooklyn, Queens**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **From the Above Analysis We can Stay that People are preferring Entire home/apt or Private room which are present in Manhattan, Brooklyn, Queens and people are preferring listings which are less in price.**

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code 
corr_df = df[['latitude','longitude','price',	'minimum_nights','number_of_reviews','reviews_per_month',	'calculated_host_listings_count',	'availability_365']].corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corr_df, annot = True, fmt='.2f', annot_kws={'size': 10},  vmax=1, square=True, cmap="Spectral")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **To check the multicollinearity problem**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **there is no strong co-relation**

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code 
sns.pairplot(df, hue="price")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# . pair plot show relationships between variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# allows us to plot pairwise relationships between variables within a dataset
# , summarising a large amount of data

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# **1. For hotel business to flourish few things which we need to consider is high revenue generation, customers satisfaction and employeee retention**
#
# **2) I would have suggested to keep moderate(average) price so that more people would visit and stay in  appartment , it would also increase  reviews per month**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# .The people who prefer to stay in Entire home or Apartment they are going to stay bit longer in that particular Neighbourhood only.
#
# .The people who prefer to stay in Private room they won't stay longer as compared to Home or Apartment.
#
# Most people prefer to pay less price.
#
# .If there are more number of Reviews for particular Neighbourhood group that means that place is a tourist place.
#
# .If people are not staying more then one night means they are travellers

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
